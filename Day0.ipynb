# %% [markdown]
# <a href="https://colab.research.google.com/github/yugan243/Qdrant-Essentials/blob/main/Day0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Qdrant Essentials: Day 0: Creating First Collection

# %% [markdown]
# ### Step 1: Install the Qdrant Client

# %%
! pip install -q qdrant-client
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.4/390.4 kB 7.6 MB/s eta 0:00:00

# %% [markdown]
# ### Step 2: Import Required Libraries

# %%
from qdrant_client import QdrantClient, models

# %% [markdown]
# ### Step 3: Connect to Qdrant Cloud

# %%
import os
from google.colab import userdata

client = QdrantClient("https://fa13d3f3-6758-4e1a-9777-f66dc4f300c2.us-east4-0.gcp.cloud.qdrant.io", api_key=userdata.get('api-key'))

# %% [markdown]
# ### Step 4: Create a Collection

# %% [markdown]
# A Collection in Qdrant is analogous to the table in relational databases. It's a container for storing vectors and its metadata.
# When creating a collection, we need to specify:
# 1. Name: A unique identifier for the collection
# 2. Vector configuration
# 3. Size: The dimentionality of vectors
# 4. Distance metric: the method used to measure similarity between vectors

# %%
collection_name = "my_first_collection"

# Create the collection with the specified vector parameters
client.create_collection(
    collection_name=collection_name,
    vectors_config=models.VectorParams(
        size=4, # Dimentionality of vectors
        distance=models.Distance.COSINE # Distance metric for similarity search
    )
)
# Out:
# True

# %% [markdown]
# ### Step 5: Verify the Collection Creation

# %%
collections = client.get_collections()
print("Existing collections: ", collections)
# Out:
# Existing collections:  collections=[CollectionDescription(name='my_first_collection'), CollectionDescription(name='points'), CollectionDescription(name='inference_test')]

# %% [markdown]
# ### Step 6: Insert the points to the collection

# %%
# Define the vecetors to be inserted
points = [
    models.PointStruct(
        id=1,
        vector=[0.1, 0.2, 0.3, 0.4],
        payload={"category": "example"}
    ),
    models.PointStruct(
        id=2,
        vector=[0.2, 0.3, 0.4, 0.5],
        payload={"category": "demo"}
    )
]

# Insert vectors to the collection
client.upsert(
    collection_name=collection_name,
    points=points
)
# Out:
# UpdateResult(operation_id=1, status=<UpdateStatus.COMPLETED: 'completed'>)

# %% [markdown]
# ### 7. Retrieving collection details

# %%
collection_info = client.get_collection(collection_name)
print("Collection info: ", collection_info)
# Out:
# Collection info:  status=<CollectionStatus.GREEN: 'green'> optimizer_status=<OptimizersStatusOneOf.OK: 'ok'> warnings=None indexed_vectors_count=0 points_count=2 segments_count=2 config=CollectionConfig(params=CollectionParams(vectors=VectorParams(size=4, distance=<Distance.COSINE: 'Cosine'>, hnsw_config=None, quantization_config=None, on_disk=None, datatype=None, multivector_config=None), shard_number=1, sharding_method=None, replication_factor=1, write_consistency_factor=1, read_fan_out_factor=None, read_fan_out_delay_ms=None, on_disk_payload=True, sparse_vectors=None), hnsw_config=HnswConfig(m=16, ef_construct=100, full_scan_threshold=10000, max_indexing_threads=0, on_disk=False, payload_m=None, inline_storage=None), optimizer_config=OptimizersConfig(deleted_threshold=0.2, vacuum_min_vector_number=1000, default_segment_number=0, max_segment_size=None, memmap_threshold=None, indexing_threshold=10000, flush_interval_sec=5, max_optimization_threads=None, prevent_unoptimized=None), wal_config=WalConfig(wal_capacity_mb=32, wal_segments_ahead=0, wal_retain_closed=1), quantization_config=None, strict_mode_config=StrictModeConfigOutput(enabled=True, max_query_limit=None, max_timeout=None, unindexed_filtering_retrieve=False, unindexed_filtering_update=False, search_max_hnsw_ef=None, search_allow_exact=None, search_max_oversampling=None, upsert_max_batchsize=None, max_collection_vector_size_bytes=None, read_rate_limit=None, write_rate_limit=None, max_collection_payload_size_bytes=None, max_points_count=None, filter_max_conditions=None, condition_max_size=None, multivector_config=None, sparse_config=None, max_payload_index_count=100), metadata=None) payload_schema={} update_queue=UpdateQueueInfo(length=0)

# %% [markdown]
# ### 8. Running a Similarity Search

# %%
query_vector = [0.08, 0.14, 0.33, 0.28]

search_results = client.query_points(
    collection_name=collection_name,
    query=query_vector,
    limit=1
)

print("Search results: ", search_results)
# Out:
# Search results:  points=[ScoredPoint(id=1, version=1, score=0.97642946, payload={'category': 'example'}, vector=None, shard_key=None, order_value=None)]

# %% [markdown]
# ### Step 9: Filtered Search

# %%
search_filter = models.Filter(
    must=[
        models.FieldCondition(
            key="category",
            match=models.MatchValue(value="example")
        )
    ]
)

filtered_results = client.query_points(
    collection_name=collection_name,
    query=query_vector,
    query_filter=search_filter,
    limit=1
)

print("Filtered search results after indexing: ", filtered_results)
# Out:
# ---------------------------------------------------------------------------
# UnexpectedResponse                        Traceback (most recent call last)
# /tmp/ipython-input-1169/3932344468.py in <cell line: 0>()
#       8 )
#       9
# ---> 10 filtered_results = client.query_points(
#      11     collection_name=collection_name,
#      12     query=query_vector,
#
# /usr/local/lib/python3.12/dist-packages/qdrant_client/qdrant_client.py in query_points(self, collection_name, query, using, prefetch, query_filter, search_params, limit, offset, with_payload, with_vectors, score_threshold, lookup_from, consistency, shard_key_selector, timeout, **kwargs)
#     421                     )
#     422
# --> 423         return self._client.query_points(
#     424             collection_name=collection_name,
#     425             query=query,
#
# /usr/local/lib/python3.12/dist-packages/qdrant_client/qdrant_remote.py in query_points(self, collection_name, query, using, prefetch, query_filter, search_params, limit, offset, with_payload, with_vectors, score_threshold, lookup_from, consistency, shard_key_selector, timeout, **kwargs)
#     536             )
#     537
# --> 538             query_result = self.http.search_api.query_points(
#     539                 collection_name=collection_name,
#     540                 consistency=consistency,
#
# /usr/local/lib/python3.12/dist-packages/qdrant_client/http/api/search_api.py in query_points(self, collection_name, consistency, timeout, query_request)
#     781         Universally query points. This endpoint covers all capabilities of search, recommend, discover, filters. But also enables hybrid and multi-stage queries.
#     782         """
# --> 783         return self._build_for_query_points(
#     784             collection_name=collection_name,
#     785             consistency=consistency,
#
# /usr/local/lib/python3.12/dist-packages/qdrant_client/http/api/search_api.py in _build_for_query_points(self, collection_name, consistency, timeout, query_request)
#     179         if "Content-Type" not in headers:
#     180             headers["Content-Type"] = "application/json"
# --> 181         return self.api_client.request(
#     182             type_=m.InlineResponse20024,
#     183             method="POST",
#
# /usr/local/lib/python3.12/dist-packages/qdrant_client/http/api_client.py in request(self, type_, method, url, path_params, **kwargs)
#      93             kwargs["timeout"] = int(kwargs["params"]["timeout"])
#      94         request = self._client.build_request(method, url, **kwargs)
# ---> 95         return self.send(request, type_)
#      96
#      97     @overload
#
# /usr/local/lib/python3.12/dist-packages/qdrant_client/http/api_client.py in send(self, request, type_)
#     128             except ValidationError as e:
#     129                 raise ResponseHandlingException(e)
# --> 130         raise UnexpectedResponse.for_response(response)
#     131
#     132     def send_inner(self, request: Request) -> Response:
#
# UnexpectedResponse: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Index required but not found for \\"category\\" of one of the following types: [keyword]. Help: Create an index for this key or use a different filter."},"time":0.000 ...'
